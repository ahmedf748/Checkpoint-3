# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
df=pd.read_csv("titanic-passengers.csv",sep=";")
df.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    NaN        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    NaN        S
# 3  female  29.0      0      4      349909  21.0750    NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 866

# %%
df.shape
# Out:
# (891, 12)

# %%
df["Age"].fillna(df["Age"].mean(),inplace=True)
df.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    NaN        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    NaN        S
# 3  female  29.0      0      4      349909  21.0750    NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
number_of_elements=len(df["Cabin"])
print("the Number of elements : ",number_of_elements)
print(df["Cabin"].value_counts())
df["Cabin"].fillna("G6",inplace=True)
df
# Out:
# the Number of elements :  891
# B96 B98        4
# C23 C25 C27    4
# G6             4
# C22 C26        3
# E101           3
#               ..
# A19            1
# C50            1
# C46            1
# B4             1
# B30            1
# Name: Cabin, Length: 147, dtype: int64
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# 2                               Jensen, Mr. Hans Peder    male  20.000000
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                               Davidson, Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.000000
# 887                              Sirayanian, Mr. Orsen    male  22.000000
# 888                                Cacic, Miss. Marija  female  30.000000
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male  29.699118
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.000000
#
#      SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0        0      0      248740  13.0000     G6        S
# 1        0      0      348123   7.6500  F G73        S
# 2        0      0      350050   7.8542     G6        S
# 3        0      4      349909  21.0750     G6        S
# 4        1      0  F.C. 12750  52.0000    B71        S
# ..     ...    ...         ...      ...    ...      ...
# 886      1      0      237736  30.0708     G6        C
# 887      0      0        2669   7.2292     G6        C
# 888      0      0      315084   8.6625     G6        S
# 889      0      0      349215   7.8958     G6        S
# 890      0      0      250655  26.0000     G6        S
#
# [891 rows x 12 columns]

# %%
a=len(df["Embarked"])
print("the elements :",a)
print(df["Embarked"].value_counts())
# Out:
# the elements : 891
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
dic={
    "Embarked":{'S':3,'C':2,"Q":1}
}
df.replace(dic,inplace=True)
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# 2                               Jensen, Mr. Hans Peder    male  20.000000
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                               Davidson, Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.000000
# 887                              Sirayanian, Mr. Orsen    male  22.000000
# 888                                Cacic, Miss. Marija  female  30.000000
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male  29.699118
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.000000
#
#      SibSp  Parch      Ticket     Fare  Cabin  Embarked
# 0        0      0      248740  13.0000     G6       3.0
# 1        0      0      348123   7.6500  F G73       3.0
# 2        0      0      350050   7.8542     G6       3.0
# 3        0      4      349909  21.0750     G6       3.0
# 4        1      0  F.C. 12750  52.0000    B71       3.0
# ..     ...    ...         ...      ...    ...       ...
# 886      1      0      237736  30.0708     G6       2.0
# 887      0      0        2669   7.2292     G6       2.0
# 888      0      0      315084   8.6625     G6       3.0
# 889      0      0      349215   7.8958     G6       3.0
# 890      0      0      250655  26.0000     G6       3.0
#
# [891 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       2
# dtype: int64

# %%
print(df['Embarked'].value_counts())
# Out:
# 3.0    644
# 2.0    168
# 1.0     77
# Name: Embarked, dtype: int64

# %%
df.shape
# Out:
# (891, 12)

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (889, 12)

# %%
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# 2                               Jensen, Mr. Hans Peder    male  20.000000
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                               Davidson, Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.000000
# 887                              Sirayanian, Mr. Orsen    male  22.000000
# 888                                Cacic, Miss. Marija  female  30.000000
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male  29.699118
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.000000
#
#      SibSp  Parch      Ticket     Fare  Cabin  Embarked
# 0        0      0      248740  13.0000     G6       3.0
# 1        0      0      348123   7.6500  F G73       3.0
# 2        0      0      350050   7.8542     G6       3.0
# 3        0      4      349909  21.0750     G6       3.0
# 4        1      0  F.C. 12750  52.0000    B71       3.0
# ..     ...    ...         ...      ...    ...       ...
# 886      1      0      237736  30.0708     G6       2.0
# 887      0      0        2669   7.2292     G6       2.0
# 888      0      0      315084   8.6625     G6       3.0
# 889      0      0      349215   7.8958     G6       3.0
# 890      0      0      250655  26.0000     G6       3.0
#
# [889 rows x 12 columns]

# %%
# Just wanted to try it 
g=sns.FacetGrid(df,col='Sex')
g.map(plt.hist,'Age',bins=10)

# %%
grid = sns.FacetGrid(df, col="Survived", size=3.2, aspect=1.)
grid.map(sns.barplot, "Sex","Age" ,alpha=0.8, ci=None)
grid.add_legend()
# Out:
# C:\Users\ahmed\anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\ahmed\anaconda3\lib\site-packages\seaborn\axisgrid.py:645: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
dic2={
    "Survived":{"Yes":1,"No":0}
}
df.replace(dic2,inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# 2                               Jensen, Mr. Hans Peder    male  20.000000
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                               Davidson, Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.000000
# 887                              Sirayanian, Mr. Orsen    male  22.000000
# 888                                Cacic, Miss. Marija  female  30.000000
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male  29.699118
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.000000
#
#      SibSp  Parch      Ticket     Fare  Cabin  Embarked
# 0        0      0      248740  13.0000     G6       3.0
# 1        0      0      348123   7.6500  F G73       3.0
# 2        0      0      350050   7.8542     G6       3.0
# 3        0      4      349909  21.0750     G6       3.0
# 4        1      0  F.C. 12750  52.0000    B71       3.0
# ..     ...    ...         ...      ...    ...       ...
# 886      1      0      237736  30.0708     G6       2.0
# 887      0      0        2669   7.2292     G6       2.0
# 888      0      0      315084   8.6625     G6       3.0
# 889      0      0      349215   7.8958     G6       3.0
# 890      0      0      250655  26.0000     G6       3.0
#
# [889 rows x 12 columns]

# %%
print(df["Pclass"].value_counts())
# Out:
# 3    491
# 1    214
# 2    184
# Name: Pclass, dtype: int64

# %%
grid = sns.FacetGrid(df,row="Sex",col="Survived", size=3.2, aspect=2.)
grid.map(sns.barplot,"Pclass","Age" ,alpha=0.8, ci=None)
grid.add_legend()
# Out:
# C:\Users\ahmed\anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\ahmed\anaconda3\lib\site-packages\seaborn\axisgrid.py:645: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
def plot_correlation_map(d):
    corr = d.corr()
    s,ax = plt.subplots(figsize =(12,10))
    cmap = sns.diverging_palette(220,10,as_cmap=True)
    s=sns.heatmap(
        corr, 
        cmap=cmap,
        square=True, 
        cbar_kws={'shrink':.9}, 
        ax=ax, 
        annot=True, 
        annot_kws ={ 'fontsize' : 12 }
    )

# %%
 plot_correlation_map(df)

# %%
# Interpretation : 
# The heatmap shows us the correlation between the variables in the data set.
# The variation in colors represents different levels of correlation.

# The correlation between variables range from -1 to 1.
# A value of -1 represents a perfect negative correlation, and a value of 1 represents a perfect positive correlation.

# A value of zero indicates that there is no correlation whatsoever between the variables.
# You’ll notice that the diagonal in the heatmap seems to have a correlation of 1, and that is because every variable is perfectly correlated with itself.
# We can observe some strong relationships here.
# The variables ‘SibSp’ and ‘Parch’ seem to have a positive correlation.
# The variables ‘Fare’ and ‘Survived’ also seem to have a positive correlation.

# %%
# Groupby function between Pclacc and Survived 
cleanup={"Suvived":{"Yes":1,"No":0}}
df.replace(cleanup,inplace=True)
df[["Pclass","Survived"]].groupby(["Pclass"],as_index=True).mean()
# Out:
#         Survived
# Pclass
# 1       0.626168
# 2       0.472826
# 3       0.242363

# %%
df.drop("Name",axis=1,inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass     Sex        Age  SibSp  Parch  \
# 0            343         0       2    male  28.000000      0      0
# 1             76         0       3    male  25.000000      0      0
# 2            641         0       3    male  20.000000      0      0
# 3            568         0       3  female  29.000000      0      4
# 4            672         0       1    male  31.000000      1      0
# ..           ...       ...     ...     ...        ...    ...    ...
# 886           10         1       2  female  14.000000      1      0
# 887           61         0       3    male  22.000000      0      0
# 888          535         0       3  female  30.000000      0      0
# 889          102         0       3    male  29.699118      0      0
# 890          428         1       2  female  19.000000      0      0
#
#          Ticket     Fare  Cabin  Embarked
# 0        248740  13.0000     G6       3.0
# 1        348123   7.6500  F G73       3.0
# 2        350050   7.8542     G6       3.0
# 3        349909  21.0750     G6       3.0
# 4    F.C. 12750  52.0000    B71       3.0
# ..          ...      ...    ...       ...
# 886      237736  30.0708     G6       2.0
# 887        2669   7.2292     G6       2.0
# 888      315084   8.6625     G6       3.0
# 889      349215   7.8958     G6       3.0
# 890      250655  26.0000     G6       3.0
#
# [889 rows x 11 columns]

# %%
print(df["Ticket"].value_counts())
# Out:
# 347082              7
# 1601                7
# CA. 2343            7
# 347088              6
# CA 2144             6
#                    ..
# 345781              1
# SOTON/O2 3101272    1
# SOTON/OQ 3101316    1
# 349214              1
# 2641                1
# Name: Ticket, Length: 680, dtype: int64

# %%
df.drop("Ticket",axis=1,inplace=True)
df.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  Cabin  \
# 0          343         0       2    male  28.0      0      0  13.0000     G6
# 1           76         0       3    male  25.0      0      0   7.6500  F G73
# 2          641         0       3    male  20.0      0      0   7.8542     G6
# 3          568         0       3  female  29.0      0      4  21.0750     G6
# 4          672         0       1    male  31.0      1      0  52.0000    B71
#
#    Embarked
# 0       3.0
# 1       3.0
# 2       3.0
# 3       3.0
# 4       3.0

# %%
print(df["Parch"].value_counts())
# Out:
# 0    676
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  Cabin  \
# 0          343         0       2    male  28.0      0      0  13.0000     G6
# 1           76         0       3    male  25.0      0      0   7.6500  F G73
# 2          641         0       3    male  20.0      0      0   7.8542     G6
# 3          568         0       3  female  29.0      0      4  21.0750     G6
# 4          672         0       1    male  31.0      1      0  52.0000    B71
#
#    Embarked
# 0       3.0
# 1       3.0
# 2       3.0
# 3       3.0
# 4       3.0

# %%
df.drop("Parch",axis=1,inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp     Fare  Cabin  \
# 0          343         0       2    male  28.0      0  13.0000     G6
# 1           76         0       3    male  25.0      0   7.6500  F G73
# 2          641         0       3    male  20.0      0   7.8542     G6
# 3          568         0       3  female  29.0      0  21.0750     G6
# 4          672         0       1    male  31.0      1  52.0000    B71
#
#    Embarked
# 0       3.0
# 1       3.0
# 2       3.0
# 3       3.0
# 4       3.0
